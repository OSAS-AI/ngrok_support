# %%
import os
import subprocess
import time
from pyngrok import ngrok, conf



# 2. Authenticate pyngrok (replace 'YOUR_AUTHTOKEN' with your actual token)
conf.get_default().auth_token = "XXX"

# 2. Kill the ngrok process entirely (optional but safer)

# 3. Now start your tunnel as usual
public_url = ngrok.connect(11434, "http", host_header="localhost:11434").public_url
print(f"Ollama is now accessible at: {public_url}")

# %%
ngrok.disconnect()
